# %%
from math import inf
def main():
    
    #f = open("I_O_file")
    count = 0
    while 1:
        
        #values = f.readline().split()
        values = input().split()
        nbReq = int(values[0])
        nbProp = int(values[1])
        
        if(nbReq == 0 and nbProp == 0):
            break
        
        if(count != 0):
            print()
            print()
        count = count + 1
        
        for i in range(nbReq):
            #f.readline()
            input()
            
        winner = ""
        nbReqChecked = 0
        winPrice = inf
        for i in range(nbProp):
            #name = f.readline()
            name = input()
            name = name[0:-1]
            #price, req  = f.readline().split()
            price, req  = input().split()
            price = float(price)
            req = int(req)
            for j in range(req):
                #f.readline()
                input()
            if(req >= nbReqChecked):
                if(req == nbReqChecked):
                    if(price < winPrice):
                        winner = name
                        winPrice = price
                        nbReqChecked = req
                else:
                    winner = name
                    winPrice = price
                    nbReqChecked = req
            
        print("RFP #{}".format(count))
        print(winner, end='')

if __name__ == "__main__":
    main()
# Out:
# RFP #1
# uYF YLT  W xK A vxyTl BzqJ
#
# RFP #2
#   X   hU  an  mK  X gU  oh C  Gd   Q Ui
#
# RFP #3
#  G   gjaD G  s o  q  Fc C mm         UIHVj  o       X
#
# RFP #4
# vW Fz   I RH
#
# RFP #5
#    KVTKnu  qSKA U O RA W K s  A WwO ioyUeNP gQ    o ooM cu  VM eU  dT q wBC
#
# RFP #6
#   n                JN K                r a       V     k
#
# RFP #7
#  I      A   I       G  s               s      i            h yu
#
# RFP #8
# ppXyjsdidaFBq
#
# RFP #9
# rXlNv f O     G S   CN We
#
# RFP #10
# z iaMCoFQng S UfO CV EO rBWJMNb a

# %%
from math import inf
def main():
    
    f = open("I_O_file")
    count = 0
    while 1:
        count = count + 1
        values = f.readline().split()
        #values = input().split()
        nbReq = int(values[0])
        nbProp = int(values[1])
        
        if(nbReq == 0 and nbProp == 0):
            break
        
        if(count != 0):
            print()
        
        for i in range(nbReq):
            f.readline()
            #input()
            
        winner = ""
        winCompliance = 0.0
        winPrice = inf
        for i in range(nbProp):
            name = f.readline()
            #name = input()
            name = name[0:-1]
            price, req  = f.readline().split()
            #price, req  = input().split()
            price = float(price)
            req = float(req)
            compliance = req/nbReq
            for j in range(int(req)):
                f.readline()
                #input()
            if(compliance >= winCompliance):
                if(compliance == winCompliance):
                    if(price < winPrice):
                        winner = name
                        winPrice = price
                        winCompliance = compliance
                winner = name
                winPrice = price
                winCompliance = compliance
        
        print("RFP #{}".format(count))
        print(winner)

if __name__ == "__main__":
    main()
# Out:
# RFP #1
#   ni
#
# RFP #2
#   X   hU  an  mK  X gU  oh C  Gd   Q Ui
#
# RFP #3
#  G   gjaD G  s o  q  Fc C mm         UIHVj  o       X
#
# RFP #4
# vW Fz   I RH
#
# RFP #5
#    KVTKnu  qSKA U O RA W K s  A WwO ioyUeNP gQ    o ooM cu  VM eU  dT q wBC
#
# RFP #6
# pRtO kJhWMEnLiyUcXovBhkd JmhSW gUS
#
# RFP #7
#  I      A   I       G  s               s      i            h yu
#
# RFP #8
# ppXyjsdidaFBq
#
# RFP #9
# rXlNv f O     G S   CN We
#
# RFP #10
# GchEpVXDWNFVXh uETBNBWWa sD cNfe obD Ma    LmZPV kkNIr K
